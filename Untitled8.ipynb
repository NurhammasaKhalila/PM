# %%
import pandas as pd

# %%
dataset ='/artistt.csv'

# %%
data = pd.read_csv(dataset)

# %%
data
# Out:
#       Unnamed: 0                         Track Name  \
# 0              0  Stereo Hearts (feat. Adam Levine)
# 1              1    Locked Away (feat. Adam Levine)
# 2              2                          Bang Bang
# 3              3      Lifestyle (feat. Adam Levine)
# 4              4                              Ojalá
# ...          ...                                ...
# 1639          27                                wHo
# 1640          28                        Fire Inside
# 1641          29                 Flames (with ZAYN)
# 1642          30                              Angel
# 1643          31  Un mundo ideal (Versión Créditos)
#
#                                   Artists  \
# 0           Gym Class Heroes, Adam Levine
# 1                    R. City, Adam Levine
# 2                     K'NAAN, Adam Levine
# 3     Jason Derulo, Adam Levine, Maroon 5
# 4       The Rudeboyz, Maluma, Adam Levine
# ...                                   ...
# ...

# %%
data.head()
# Out:
#    Unnamed: 0                         Track Name  \
# 0           0  Stereo Hearts (feat. Adam Levine)
# 1           1    Locked Away (feat. Adam Levine)
# 2           2                          Bang Bang
# 3           3      Lifestyle (feat. Adam Levine)
# 4           4                              Ojalá
#
#                                Artists                     Album Name  \
# 0        Gym Class Heroes, Adam Levine     The Papercut Chronicles II
# 1                 R. City, Adam Levine        What Dreams Are Made Of
# 2                  K'NAAN, Adam Levine                     Troubadour
# 3  Jason Derulo, Adam Levine, Maroon 5  Lifestyle (feat. Adam Levine)
# 4    The Rudeboyz, Maluma, Adam Levine                          Ojalá
#
#                  Album ID                Track ID  Popularity Release Date  \
# 0  2mumCpGmuE9iDeOvMx6XrB  0qOnSQQF0yzuPWsXrQ9paz          83   11/11/2011
# 1  4AUTMNSP56xicSznzKgzjB  7x5xYW5W42OGPAdHUyyguy          79    10/9/2015
# ...

# %%
print(data.dtypes)
# Out:
# Unnamed: 0            int64
# Track Name           object
# Artists              object
# Album Name           object
# Album ID             object
# Track ID             object
# Popularity            int64
# Release Date         object
# Duration (ms)         int64
# Explicit               bool
# External URLs        object
# Danceability        float64
# Energy              float64
# Key                   int64
# Loudness            float64
# Mode                  int64
# Speechiness         float64
# Acousticness        float64
# Instrumentalness    float64
# Liveness            float64
# Valence             float64
# Tempo               float64
# dtype: object

# %%
datanoid =data.drop(data.columns[4],axis=1)

# %%
datanoid
# Out:
#       Unnamed: 0                         Track Name  \
# 0              0  Stereo Hearts (feat. Adam Levine)
# 1              1    Locked Away (feat. Adam Levine)
# 2              2                          Bang Bang
# 3              3      Lifestyle (feat. Adam Levine)
# 4              4                              Ojalá
# ...          ...                                ...
# 1639          27                                wHo
# 1640          28                        Fire Inside
# 1641          29                 Flames (with ZAYN)
# 1642          30                              Angel
# 1643          31  Un mundo ideal (Versión Créditos)
#
#                                   Artists  \
# 0           Gym Class Heroes, Adam Levine
# 1                    R. City, Adam Levine
# 2                     K'NAAN, Adam Levine
# 3     Jason Derulo, Adam Levine, Maroon 5
# 4       The Rudeboyz, Maluma, Adam Levine
# ...                                   ...
# ...

# %%
data.describe()
# Out:
#         Unnamed: 0   Popularity  Duration (ms)  Danceability       Energy  \
# count  1644.000000  1644.000000    1644.000000   1644.000000  1644.000000
# mean     28.419100    64.572384  214467.218370      0.616231     0.654658
# std      19.986365    13.504545   47647.216797      0.135346     0.186302
# min       0.000000     0.000000   13578.000000      0.000000     0.051900
# 25%      13.000000    57.000000  185822.500000      0.530750     0.548000
# 50%      26.000000    65.000000  210938.500000      0.629000     0.679000
# 75%      40.000000    74.000000  235752.000000      0.707250     0.794250
# max      99.000000    98.000000  618960.000000      0.972000     0.995000
#
#                Key     Loudness         Mode  Speechiness  Acousticness  \
# count  1644.000000  1644.000000  1644.000000  1644.000000   1644.000000
# mean      5.232968    -6.413063     0.594282     0.076479      0.209304
# std       3.629508     2.530215     0.491180     0.069310      0.257729
# ...

# %%
data.loc[:,"Popularity":].corr()
# Out:
# <ipython-input-17-de9c168f6135>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.loc[:,"Popularity":].corr()
#                   Popularity  Duration (ms)  Explicit  Danceability    Energy  \
# Popularity          1.000000       0.085795  0.079788      0.049455 -0.092602
# Duration (ms)       0.085795       1.000000  0.009963     -0.129183 -0.039055
# Explicit            0.079788       0.009963  1.000000      0.178148 -0.024094
# Danceability        0.049455      -0.129183  0.178148      1.000000  0.115215
# Energy             -0.092602      -0.039055 -0.024094      0.115215  1.000000
# Key                -0.057595      -0.049830 -0.010272      0.039686  0.040384
# Loudness           -0.036402      -0.042546  0.008513      0.218575  0.695995
# ...

# %%
# @title Popularity vs Duration

from matplotlib import pyplot as plt
data.plot(kind='scatter', x='Popularity', y='Tempo', s=32, alpha=.8)
plt.gca().spines[['top','right',]].set_visible(False)

# %%
# !pip install kaggle

# %%
import os
from google.colab import files

# Pastikan file kaggle.json sudah diunggah
if not os.path.exists("/root/.kaggle/kaggle.json"):
    uploaded = files.upload()
    for fn in uploaded.keys():
        print('User uploaded file "{name}" with length {length} bytes'.format(
            name=fn, length=len(uploaded[fn])))
    # Pindahkan file kaggle.json ke direktori yang tepat
    # !mkdir -p ~/.kaggle
    # !mv kaggle.json ~/.kaggle/
    # !chmod 600 /root/.kaggle/kaggle.json
# Out:
#      <input type="file" id="files-dd4f380c-9783-4d17-9433-7437333b594f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-dd4f380c-9783-4d17-9433-7437333b594f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !kaggle datasets list -s "Spotify music of top artists"
# Out:
# ...
# ref                                                   title                                           size  lastUpdated          downloadCount  voteCount  usabilityRating
# ----------------------------------------------------  ---------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# rakkesharv/spotify-top-10000-streamed-songs           Spotify Top 10000 Streamed Songs               280KB  2023-01-02 08:17:15           7061        128  1.0
# edumucelli/spotifys-worldwide-daily-song-ranking      Spotify's Worldwide Daily Song Ranking          43MB  2018-01-12 20:32:57          14119        362  0.7352941
# joebeachcapital/top-10000-spotify-songs-1960-now      Top 10000 Songs on Spotify 1960-Now              2MB  2023-07-26 00:54:14           3565         80  1.0
# salvatorerastelli/spotify-and-youtube                 Spotify and Youtube                              9MB  2023-03-20 15:43:25          24006        544  1.0
# ...

# %%
# !kaggle datasets download rakkesharv/spotify-top-10000-streamed-songs
# Out:
# ...
#   0% 0.00/280k [00:00<?, ?B/s]
# 100% 280k/280k [00:00<00:00, 46.9MB/s]

# %%
# !unzip /content/spotify-top-10000-streamed-songs.zip
# Out:
# Archive:  /content/spotify-top-10000-streamed-songs.zip
#   inflating: Spotify_final_dataset.csv

# %%
pd.read_csv('Spotify_final_dataset.csv')
# Out:
#        Position         Artist Name  \
# 0             1        Post Malone
# 1             2         Juice WRLD
# 2             3       Lil Uzi Vert
# 3             4            J. Cole
# 4             5        Post Malone
# ...         ...                 ...
# 11079     11080     The Band Perry
# 11080     11081  Justin Timberlake
# 11081     11082      Mike WiLL Made
# 11082     11083          The Vamps
# 11083     11084                 JAY
#
#                                         Song Name  Days  Top 10 (xTimes)  \
# 0      Sunflower  SpiderMan: Into the SpiderVerse  1506            302.0
# 1                                    Lucid Dreams  1673            178.0
# 2                                   XO TOUR Llif3  1853            212.0
# 3                                  No Role Modelz  2547              6.0
# 4                                        rockstar  1223            186.0
# ...                                           ...   ...              ...
# ...
